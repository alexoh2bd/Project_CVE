# %%
import matplotlib.pyplot as plt
import polars as pl
import numpy as np
import seaborn as sns



cvss_v3_path = "../data/merged/cvss_v3_combined1.csv"
df = pl.read_csv(cvss_v3_path)
df.head()
# Out:
# shape: (5, 18)
# ┌─────┬────────────┬────────────┬───────────┬───┬────────────┬────────────┬────────────┬───────────┐
# │     ┆ cve_id     ┆ source     ┆ type      ┆ … ┆ integrity_ ┆ availabili ┆ exploitabi ┆ impact_sc │
# │ --- ┆ ---        ┆ ---        ┆ ---       ┆   ┆ impact     ┆ ty_impact  ┆ lity_score ┆ ore       │
# │ i64 ┆ str        ┆ str        ┆ str       ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │     ┆            ┆            ┆           ┆   ┆ str        ┆ str        ┆ f64        ┆ f64       │
# ╞═════╪════════════╪════════════╪═══════════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ 0   ┆ CVE-2024-5 ┆ 134c704f-9 ┆ Secondary ┆ … ┆ HIGH       ┆ HIGH       ┆ 3.9        ┆ 5.9       │
# │     ┆ 5560       ┆ b21-4f2e-9 ┆           ┆   ┆            ┆            ┆            ┆           │
# │     ┆            ┆ 1b3-4a4673 ┆           ┆   ┆            ┆            ┆            ┆           │
# ...

# %%
boxprops = dict(linestyle='--', linewidth=3, color='darkgoldenrod')

# fig, axs = plt.subplots(nrows=1,ncols=1, figsize=(12,12), sharey = True)
# axs[0,0] = plt.boxplot(base_severity,)

sns.boxplot(data=df, x="base_severity",y="base_score")
# Out:
# <Axes: xlabel='base_severity', ylabel='base_score'>

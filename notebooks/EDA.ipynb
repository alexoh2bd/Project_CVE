# %%
import pandas as pd

# %%
df = pd.read_csv("../data/merged/Main1.csv", nrows=10000)
df.drop(['version_end_including', 'criteria', 'match_criteria_id','version','vector_string'],axis=1, inplace=True)
df.dropna(inplace=True)
print(df.columns)
df.head()
# Out:
# Index(['cve_id', 'source_identifier', 'published_date', 'last_modified_date',
#        'vuln_status', 'exploited', 'vulnerable', 'source', 'type_x',
#        'base_score', 'base_severity', 'attack_vector', 'attack_complexity',
#        'privileges_required', 'user_interaction', 'scope',
#        'confidentiality_impact', 'integrity_impact', 'availability_impact',
#        'exploitability_score', 'impact_score', 'cwe_id'],
#       dtype='object')
#            cve_id source_identifier           published_date  \
# 0  CVE-2022-47950     cve@mitre.org  2023-01-18T17:15:10.290
# 1  CVE-2022-47950     cve@mitre.org  2023-01-18T17:15:10.290
# 2  CVE-2022-47950     cve@mitre.org  2023-01-18T17:15:10.290
# 3  CVE-2022-47950     cve@mitre.org  2023-01-18T17:15:10.290
# 4  CVE-2022-47950     cve@mitre.org  2023-01-18T17:15:10.290
#
#         last_modified_date vuln_status  exploited vulnerable  \
# 0  2025-04-04T16:15:16.630    Modified          0       True
# ...

# %%
df.info()
df['source_identifier'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9864 entries, 0 to 9999
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   cve_id                  9864 non-null   object
#  1   source_identifier       9864 non-null   object
#  2   published_date          9864 non-null   object
#  3   last_modified_date      9864 non-null   object
#  4   vuln_status             9864 non-null   object
#  5   exploited               9864 non-null   int64
#  6   vulnerable              9864 non-null   object
#  7   source                  9864 non-null   object
#  8   type_x                  9864 non-null   object
#  9   base_score              9864 non-null   float64
#  10  base_severity           9864 non-null   object
#  11  attack_vector           9864 non-null   object
#  12  attack_complexity       9864 non-null   object
#  13  privileges_required     9864 non-null   object
# ...
